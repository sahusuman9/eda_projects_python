# %% [markdown]
# # Healthcare Patient Records
# ### Problem Statement:
#     -Clean and explore patient data. Handle missing age/gender values, calculate bill stats, and analyze diagnosis patterns over time.
#     -Key Techniques: .dropna(), .replace(), .mean(), .apply(), .astype(), np.select(), np.isnan()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('healthcare_patients.csv')
df = df.copy()
df
# Out:
#     Patient_ID   Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001  55.0     NaN     2024-01-01      NaN   Malaria          NaN
# 1         5002  55.0  Female     2024-01-03    Fever       Flu          NaN
# 2         5003  55.0     NaN     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004  45.0    Male     2024-01-07      NaN   Typhoid       7500.0
# 4         5005  55.0    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006  55.0    Male     2024-01-11      NaN   Typhoid       5000.0
# 6         5007   NaN    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008  55.0     NaN     2024-01-15    Fever   Malaria      11000.0
# 8         5009  45.0     NaN     2024-01-17      NaN   Malaria       9000.0
# 9         5010   NaN    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011   NaN     NaN     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012  25.0  Female     2024-01-23      NaN   Typhoid       5000.0
# 12        5013  55.0  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014  55.0  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015  25.0    Male     2024-01-29    Cough   Malaria          NaN
# 15        5016  55.0  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017  35.0     NaN     2024-02-02    Cough  COVID-19          NaN
# 17        5018  25.0  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019  45.0     NaN     2024-02-06      NaN   Typhoid       9000.0
# 19        5020  45.0     NaN     2024-02-08      NaN       Flu       7500.0
# 20        5021  45.0  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022  25.0    Male     2024-02-12  Fatigue  COVID-19          NaN
# 22        5023  45.0  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024  35.0     NaN     2024-02-16    Cough  COVID-19      11000.0
# 24        5025   NaN     NaN     2024-02-18      NaN       Flu       7500.0
# 25        5026  25.0    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027   NaN    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028   NaN    Male     2024-02-24   Nausea   Malaria          NaN
# 28        5029  35.0     NaN     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030  55.0    Male     2024-02-28      NaN       Flu       5000.0
# 30        5031  35.0  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032   NaN    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033  35.0     NaN     2024-03-05    Cough   Typhoid       9000.0
# 33        5034  45.0     NaN     2024-03-07    Cough   Typhoid       5000.0
# 34        5035  35.0    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036  25.0  Female     2024-03-11      NaN   Typhoid      11000.0
# 36        5037  25.0  Female     2024-03-13    Fever   Typhoid          NaN
# 37        5038  45.0     NaN     2024-03-15   Nausea       Flu       7500.0
# 38        5039   NaN  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040  35.0     NaN     2024-03-19      NaN   Typhoid          NaN
# 40        5041  25.0    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042  25.0  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043  55.0  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044  35.0    Male     2024-03-27    Cough       Flu          NaN
# 44        5045  25.0  Female     2024-03-29      NaN   Malaria      11000.0
# 45        5046   NaN  Female     2024-03-31      NaN  COVID-19       9000.0
# 46        5047  55.0     NaN     2024-04-02    Fever   Malaria          NaN
# 47        5048  45.0     NaN     2024-04-04  Fatigue       Flu       9000.0
# 48        5049  55.0    Male     2024-04-06    Cough   Malaria          NaN
# 49        5050   NaN     NaN     2024-04-08   Nausea   Typhoid       5000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      50 non-null     int64
#  1   Age             40 non-null     float64
#  2   Gender          32 non-null     object
#  3   Admission_Date  50 non-null     object
#  4   Symptoms        37 non-null     object
#  5   Diagnosis       50 non-null     object
#  6   Bill_Amount     39 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# Patient_ID         0
# Age               10
# Gender            18
# Admission_Date     0
# Symptoms          13
# Diagnosis          0
# Bill_Amount       11
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 55.0    13
# 25.0    10
# 45.0     9
# 35.0     8
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(41.25)

# %%
df.fillna({"Age": df['Age'].mean().round()}, inplace=True)

# %%
df
# Out:
#     Patient_ID   Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001  55.0     NaN     2024-01-01      NaN   Malaria          NaN
# 1         5002  55.0  Female     2024-01-03    Fever       Flu          NaN
# 2         5003  55.0     NaN     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004  45.0    Male     2024-01-07      NaN   Typhoid       7500.0
# 4         5005  55.0    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006  55.0    Male     2024-01-11      NaN   Typhoid       5000.0
# 6         5007  41.0    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008  55.0     NaN     2024-01-15    Fever   Malaria      11000.0
# 8         5009  45.0     NaN     2024-01-17      NaN   Malaria       9000.0
# 9         5010  41.0    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011  41.0     NaN     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012  25.0  Female     2024-01-23      NaN   Typhoid       5000.0
# 12        5013  55.0  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014  55.0  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015  25.0    Male     2024-01-29    Cough   Malaria          NaN
# 15        5016  55.0  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017  35.0     NaN     2024-02-02    Cough  COVID-19          NaN
# 17        5018  25.0  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019  45.0     NaN     2024-02-06      NaN   Typhoid       9000.0
# 19        5020  45.0     NaN     2024-02-08      NaN       Flu       7500.0
# 20        5021  45.0  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022  25.0    Male     2024-02-12  Fatigue  COVID-19          NaN
# 22        5023  45.0  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024  35.0     NaN     2024-02-16    Cough  COVID-19      11000.0
# 24        5025  41.0     NaN     2024-02-18      NaN       Flu       7500.0
# 25        5026  25.0    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027  41.0    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028  41.0    Male     2024-02-24   Nausea   Malaria          NaN
# 28        5029  35.0     NaN     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030  55.0    Male     2024-02-28      NaN       Flu       5000.0
# 30        5031  35.0  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032  41.0    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033  35.0     NaN     2024-03-05    Cough   Typhoid       9000.0
# 33        5034  45.0     NaN     2024-03-07    Cough   Typhoid       5000.0
# 34        5035  35.0    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036  25.0  Female     2024-03-11      NaN   Typhoid      11000.0
# 36        5037  25.0  Female     2024-03-13    Fever   Typhoid          NaN
# 37        5038  45.0     NaN     2024-03-15   Nausea       Flu       7500.0
# 38        5039  41.0  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040  35.0     NaN     2024-03-19      NaN   Typhoid          NaN
# 40        5041  25.0    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042  25.0  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043  55.0  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044  35.0    Male     2024-03-27    Cough       Flu          NaN
# 44        5045  25.0  Female     2024-03-29      NaN   Malaria      11000.0
# 45        5046  41.0  Female     2024-03-31      NaN  COVID-19       9000.0
# 46        5047  55.0     NaN     2024-04-02    Fever   Malaria          NaN
# 47        5048  45.0     NaN     2024-04-04  Fatigue       Flu       9000.0
# 48        5049  55.0    Male     2024-04-06    Cough   Malaria          NaN
# 49        5050  41.0     NaN     2024-04-08   Nausea   Typhoid       5000.0

# %%
df.isnull().sum()
# Out:
# Patient_ID         0
# Age                0
# Gender            18
# Admission_Date     0
# Symptoms          13
# Diagnosis          0
# Bill_Amount       11
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    16
# Male      16
# Name: count, dtype: int64

# %%
#replacing null values randomly with male or female in gender column
null_index = df[df['Gender'].isnull()].index    #finds indesx with null values

# %%
df.loc[null_index, 'Gender'] = np.random.choice(['Male','Female'], size=len(null_index))   #fills values one at a time randomly

# %%
df
# Out:
#     Patient_ID   Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001  55.0  Female     2024-01-01      NaN   Malaria          NaN
# 1         5002  55.0  Female     2024-01-03    Fever       Flu          NaN
# 2         5003  55.0  Female     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004  45.0    Male     2024-01-07      NaN   Typhoid       7500.0
# 4         5005  55.0    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006  55.0    Male     2024-01-11      NaN   Typhoid       5000.0
# 6         5007  41.0    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008  55.0  Female     2024-01-15    Fever   Malaria      11000.0
# 8         5009  45.0  Female     2024-01-17      NaN   Malaria       9000.0
# 9         5010  41.0    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011  41.0  Female     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012  25.0  Female     2024-01-23      NaN   Typhoid       5000.0
# 12        5013  55.0  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014  55.0  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015  25.0    Male     2024-01-29    Cough   Malaria          NaN
# 15        5016  55.0  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017  35.0  Female     2024-02-02    Cough  COVID-19          NaN
# 17        5018  25.0  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019  45.0    Male     2024-02-06      NaN   Typhoid       9000.0
# 19        5020  45.0    Male     2024-02-08      NaN       Flu       7500.0
# 20        5021  45.0  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022  25.0    Male     2024-02-12  Fatigue  COVID-19          NaN
# 22        5023  45.0  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024  35.0    Male     2024-02-16    Cough  COVID-19      11000.0
# 24        5025  41.0    Male     2024-02-18      NaN       Flu       7500.0
# 25        5026  25.0    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027  41.0    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028  41.0    Male     2024-02-24   Nausea   Malaria          NaN
# 28        5029  35.0  Female     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030  55.0    Male     2024-02-28      NaN       Flu       5000.0
# 30        5031  35.0  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032  41.0    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033  35.0  Female     2024-03-05    Cough   Typhoid       9000.0
# 33        5034  45.0  Female     2024-03-07    Cough   Typhoid       5000.0
# 34        5035  35.0    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036  25.0  Female     2024-03-11      NaN   Typhoid      11000.0
# 36        5037  25.0  Female     2024-03-13    Fever   Typhoid          NaN
# 37        5038  45.0  Female     2024-03-15   Nausea       Flu       7500.0
# 38        5039  41.0  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040  35.0    Male     2024-03-19      NaN   Typhoid          NaN
# 40        5041  25.0    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042  25.0  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043  55.0  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044  35.0    Male     2024-03-27    Cough       Flu          NaN
# 44        5045  25.0  Female     2024-03-29      NaN   Malaria      11000.0
# 45        5046  41.0  Female     2024-03-31      NaN  COVID-19       9000.0
# 46        5047  55.0    Male     2024-04-02    Fever   Malaria          NaN
# 47        5048  45.0    Male     2024-04-04  Fatigue       Flu       9000.0
# 48        5049  55.0    Male     2024-04-06    Cough   Malaria          NaN
# 49        5050  41.0    Male     2024-04-08   Nausea   Typhoid       5000.0

# %%
df.isnull().sum()
# Out:
# Patient_ID         0
# Age                0
# Gender             0
# Admission_Date     0
# Symptoms          13
# Diagnosis          0
# Bill_Amount       11
# dtype: int64

# %%
df['Symptoms'].value_counts()
# Out:
# Symptoms
# Cough      11
# Fatigue    10
# Fever       8
# Nausea      8
# Name: count, dtype: int64

# %%
df['Symptoms'].dropna().unique()
# Out:
# array(['Fever', 'Fatigue', 'Nausea', 'Cough'], dtype=object)

# %%
null_index = df[df['Symptoms'].isnull()].index
df.loc[null_index, 'Symptoms'] = np.random.choice(df['Symptoms'].dropna().unique(), size=len(null_index))

# %%
df
# Out:
#     Patient_ID   Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001  55.0  Female     2024-01-01    Cough   Malaria          NaN
# 1         5002  55.0  Female     2024-01-03    Fever       Flu          NaN
# 2         5003  55.0  Female     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004  45.0    Male     2024-01-07   Nausea   Typhoid       7500.0
# 4         5005  55.0    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006  55.0    Male     2024-01-11    Fever   Typhoid       5000.0
# 6         5007  41.0    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008  55.0  Female     2024-01-15    Fever   Malaria      11000.0
# 8         5009  45.0  Female     2024-01-17   Nausea   Malaria       9000.0
# 9         5010  41.0    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011  41.0  Female     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012  25.0  Female     2024-01-23  Fatigue   Typhoid       5000.0
# 12        5013  55.0  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014  55.0  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015  25.0    Male     2024-01-29    Cough   Malaria          NaN
# 15        5016  55.0  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017  35.0  Female     2024-02-02    Cough  COVID-19          NaN
# 17        5018  25.0  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019  45.0    Male     2024-02-06    Fever   Typhoid       9000.0
# 19        5020  45.0    Male     2024-02-08    Fever       Flu       7500.0
# 20        5021  45.0  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022  25.0    Male     2024-02-12  Fatigue  COVID-19          NaN
# 22        5023  45.0  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024  35.0    Male     2024-02-16    Cough  COVID-19      11000.0
# 24        5025  41.0    Male     2024-02-18   Nausea       Flu       7500.0
# 25        5026  25.0    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027  41.0    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028  41.0    Male     2024-02-24   Nausea   Malaria          NaN
# 28        5029  35.0  Female     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030  55.0    Male     2024-02-28    Cough       Flu       5000.0
# 30        5031  35.0  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032  41.0    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033  35.0  Female     2024-03-05    Cough   Typhoid       9000.0
# 33        5034  45.0  Female     2024-03-07    Cough   Typhoid       5000.0
# 34        5035  35.0    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036  25.0  Female     2024-03-11  Fatigue   Typhoid      11000.0
# 36        5037  25.0  Female     2024-03-13    Fever   Typhoid          NaN
# 37        5038  45.0  Female     2024-03-15   Nausea       Flu       7500.0
# 38        5039  41.0  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040  35.0    Male     2024-03-19  Fatigue   Typhoid          NaN
# 40        5041  25.0    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042  25.0  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043  55.0  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044  35.0    Male     2024-03-27    Cough       Flu          NaN
# 44        5045  25.0  Female     2024-03-29    Fever   Malaria      11000.0
# 45        5046  41.0  Female     2024-03-31    Fever  COVID-19       9000.0
# 46        5047  55.0    Male     2024-04-02    Fever   Malaria          NaN
# 47        5048  45.0    Male     2024-04-04  Fatigue       Flu       9000.0
# 48        5049  55.0    Male     2024-04-06    Cough   Malaria          NaN
# 49        5050  41.0    Male     2024-04-08   Nausea   Typhoid       5000.0

# %%
df.isnull().sum()
# Out:
# Patient_ID         0
# Age                0
# Gender             0
# Admission_Date     0
# Symptoms           0
# Diagnosis          0
# Bill_Amount       11
# dtype: int64

# %%
df.fillna({"Bill_Amount": df['Bill_Amount'].mean().round()}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Patient_ID        0
# Age               0
# Gender            0
# Admission_Date    0
# Symptoms          0
# Diagnosis         0
# Bill_Amount       0
# dtype: int64

# %%
df
# Out:
#     Patient_ID   Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001  55.0  Female     2024-01-01    Cough   Malaria       7731.0
# 1         5002  55.0  Female     2024-01-03    Fever       Flu       7731.0
# 2         5003  55.0  Female     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004  45.0    Male     2024-01-07   Nausea   Typhoid       7500.0
# 4         5005  55.0    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006  55.0    Male     2024-01-11    Fever   Typhoid       5000.0
# 6         5007  41.0    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008  55.0  Female     2024-01-15    Fever   Malaria      11000.0
# 8         5009  45.0  Female     2024-01-17   Nausea   Malaria       9000.0
# 9         5010  41.0    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011  41.0  Female     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012  25.0  Female     2024-01-23  Fatigue   Typhoid       5000.0
# 12        5013  55.0  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014  55.0  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015  25.0    Male     2024-01-29    Cough   Malaria       7731.0
# 15        5016  55.0  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017  35.0  Female     2024-02-02    Cough  COVID-19       7731.0
# 17        5018  25.0  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019  45.0    Male     2024-02-06    Fever   Typhoid       9000.0
# 19        5020  45.0    Male     2024-02-08    Fever       Flu       7500.0
# 20        5021  45.0  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022  25.0    Male     2024-02-12  Fatigue  COVID-19       7731.0
# 22        5023  45.0  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024  35.0    Male     2024-02-16    Cough  COVID-19      11000.0
# 24        5025  41.0    Male     2024-02-18   Nausea       Flu       7500.0
# 25        5026  25.0    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027  41.0    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028  41.0    Male     2024-02-24   Nausea   Malaria       7731.0
# 28        5029  35.0  Female     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030  55.0    Male     2024-02-28    Cough       Flu       5000.0
# 30        5031  35.0  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032  41.0    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033  35.0  Female     2024-03-05    Cough   Typhoid       9000.0
# 33        5034  45.0  Female     2024-03-07    Cough   Typhoid       5000.0
# 34        5035  35.0    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036  25.0  Female     2024-03-11  Fatigue   Typhoid      11000.0
# 36        5037  25.0  Female     2024-03-13    Fever   Typhoid       7731.0
# 37        5038  45.0  Female     2024-03-15   Nausea       Flu       7500.0
# 38        5039  41.0  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040  35.0    Male     2024-03-19  Fatigue   Typhoid       7731.0
# 40        5041  25.0    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042  25.0  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043  55.0  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044  35.0    Male     2024-03-27    Cough       Flu       7731.0
# 44        5045  25.0  Female     2024-03-29    Fever   Malaria      11000.0
# 45        5046  41.0  Female     2024-03-31    Fever  COVID-19       9000.0
# 46        5047  55.0    Male     2024-04-02    Fever   Malaria       7731.0
# 47        5048  45.0    Male     2024-04-04  Fatigue       Flu       9000.0
# 48        5049  55.0    Male     2024-04-06    Cough   Malaria       7731.0
# 49        5050  41.0    Male     2024-04-08   Nausea   Typhoid       5000.0

# %%
df["Age"] = df["Age"].astype(int)

# %%
df
# Out:
#     Patient_ID  Age  Gender Admission_Date Symptoms Diagnosis  Bill_Amount
# 0         5001   55  Female     2024-01-01    Cough   Malaria       7731.0
# 1         5002   55  Female     2024-01-03    Fever       Flu       7731.0
# 2         5003   55  Female     2024-01-05  Fatigue  COVID-19       9000.0
# 3         5004   45    Male     2024-01-07   Nausea   Typhoid       7500.0
# 4         5005   55    Male     2024-01-09   Nausea       Flu       9000.0
# 5         5006   55    Male     2024-01-11    Fever   Typhoid       5000.0
# 6         5007   41    Male     2024-01-13   Nausea  COVID-19      11000.0
# 7         5008   55  Female     2024-01-15    Fever   Malaria      11000.0
# 8         5009   45  Female     2024-01-17   Nausea   Malaria       9000.0
# 9         5010   41    Male     2024-01-19  Fatigue       Flu       5000.0
# 10        5011   41  Female     2024-01-21  Fatigue   Malaria       5000.0
# 11        5012   25  Female     2024-01-23  Fatigue   Typhoid       5000.0
# 12        5013   55  Female     2024-01-25    Cough   Malaria       5000.0
# 13        5014   55  Female     2024-01-27  Fatigue   Malaria       9000.0
# 14        5015   25    Male     2024-01-29    Cough   Malaria       7731.0
# 15        5016   55  Female     2024-01-31    Cough       Flu       5000.0
# 16        5017   35  Female     2024-02-02    Cough  COVID-19       7731.0
# 17        5018   25  Female     2024-02-04    Fever   Malaria       7500.0
# 18        5019   45    Male     2024-02-06    Fever   Typhoid       9000.0
# 19        5020   45    Male     2024-02-08    Fever       Flu       7500.0
# 20        5021   45  Female     2024-02-10  Fatigue       Flu       9000.0
# 21        5022   25    Male     2024-02-12  Fatigue  COVID-19       7731.0
# 22        5023   45  Female     2024-02-14   Nausea  COVID-19       7500.0
# 23        5024   35    Male     2024-02-16    Cough  COVID-19      11000.0
# 24        5025   41    Male     2024-02-18   Nausea       Flu       7500.0
# 25        5026   25    Male     2024-02-20    Fever   Malaria       7500.0
# 26        5027   41    Male     2024-02-22    Fever   Typhoid       9000.0
# 27        5028   41    Male     2024-02-24   Nausea   Malaria       7731.0
# 28        5029   35  Female     2024-02-26  Fatigue   Malaria       7500.0
# 29        5030   55    Male     2024-02-28    Cough       Flu       5000.0
# 30        5031   35  Female     2024-03-01    Cough   Malaria       9000.0
# 31        5032   41    Male     2024-03-03   Nausea       Flu       7500.0
# 32        5033   35  Female     2024-03-05    Cough   Typhoid       9000.0
# 33        5034   45  Female     2024-03-07    Cough   Typhoid       5000.0
# 34        5035   35    Male     2024-03-09  Fatigue   Typhoid       5000.0
# 35        5036   25  Female     2024-03-11  Fatigue   Typhoid      11000.0
# 36        5037   25  Female     2024-03-13    Fever   Typhoid       7731.0
# 37        5038   45  Female     2024-03-15   Nausea       Flu       7500.0
# 38        5039   41  Female     2024-03-17    Fever   Malaria       5000.0
# 39        5040   35    Male     2024-03-19  Fatigue   Typhoid       7731.0
# 40        5041   25    Male     2024-03-21  Fatigue  COVID-19       5000.0
# 41        5042   25  Female     2024-03-23   Nausea   Malaria      11000.0
# 42        5043   55  Female     2024-03-25    Cough   Malaria       9000.0
# 43        5044   35    Male     2024-03-27    Cough       Flu       7731.0
# 44        5045   25  Female     2024-03-29    Fever   Malaria      11000.0
# 45        5046   41  Female     2024-03-31    Fever  COVID-19       9000.0
# 46        5047   55    Male     2024-04-02    Fever   Malaria       7731.0
# 47        5048   45    Male     2024-04-04  Fatigue       Flu       9000.0
# 48        5049   55    Male     2024-04-06    Cough   Malaria       7731.0
# 49        5050   41    Male     2024-04-08   Nausea   Typhoid       5000.0

# %%
df.to_csv("cleaned_hospital_data.csv", index = False)
